# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               101 non-null    object
#  1   Time (UTC)         101 non-null    object
#  2   Booster_Version    101 non-null    object
#  3   Launch_Site        101 non-null    object
#  4   Payload            101 non-null    object
#  5   PAYLOAD_MASS__KG_  101 non-null    int64
#  6   Orbit              101 non-null    object
#  7   Customer           101 non-null    object
#  8   Mission_Outcome    101 non-null    object
#  9   Landing_Outcome    101 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 8.0+ KB

# %%
df.head(2)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)

# %%
set(df['Launch_Site'])
# Out:
# {'CCAFS LC-40', 'CCAFS SLC-40', 'KSC LC-39A', 'VAFB SLC-4E'}

# %%
df_CCA= df[df['Launch_Site'].str.contains("CCA")]
df_CCA.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
print(set(df['Customer']))
# Out:
# {'PSN, SpaceIL / IAI', 'NRO', 'MDA', 'Es hailSat', 'SES', 'SKY Perfect JSAT Group', 'Orbcomm', 'Spaceflight Industries', 'NASA (COTS)', 'U.S. Air Force NASA NOAA', 'Northrop Grumman', 'USSF', 'EchoStar', 'NSPO', 'Republic of Korea Army, Spaceflight Industries (BlackSky)', 'NASA (LSP) NOAA CNES', 'NASA (LSP)', 'Hispasat  NovaWurks', 'SpaceX, Planet Labs', 'NASA (COTS) NRO', 'CONAE, PlanetIQ, SpaceX', 'SpaceX', 'U.S. Space Force', 'NASA (CCP)', 'NASA (CRS), Kacific 1', 'Thaicom', 'SpaceX, Planet Labs, PlanetIQ', 'Sky Perfect JSAT, Kacific 1', 'ABS Eutelsat', 'Iridium Communications GFZ ‚ NASA', 'Spacecom', 'NASA / NOAA / ESA / EUMETSAT', 'USAF', 'NASA (CTS)', 'KT Corporation', 'CONAE', 'Iridium Communications', 'Intelsat', 'SpaceX, Spaceflight Industries (BlackSky), Planet Labs', 'Turkmenistan National Space Agency', 'NASA (CCDev)', 'Telkom Indonesia', 'Inmarsat', 'Thales-Alenia/BTRC', 'SES EchoStar', 'NASA (CCD) ', 'AsiaSat', 'Bulsatcom', 'Canadian Space Agency (CSA)', 'Hisdesat exact
# ...

# %%
df_NASACRS= df[df['Customer']==('NASA (CRS)')]

# %%
df_MASS= df_NASACRS[['Customer','PAYLOAD_MASS__KG_']]
df_MASS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 3 to 100
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer           20 non-null     object
#  1   PAYLOAD_MASS__KG_  20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 480.0+ bytes

# %%
print(set(df['Booster_Version']))
# Out:
# {'F9 B5  B1046.1', 'F9 B5 B1060.2 ', 'F9 B5B1056.1 ', 'F9 B4  B1039.2', 'F9 B5 B1048.5', 'F9 B4 B1042.1', 'F9 B4 B1044', 'F9 B5B1047.1', 'F9 FT B1021.1', 'F9 v1.1  B1003', 'F9 FT B1037', 'F9 FT B1029.1', 'F9 B5B1048.1', 'F9 FT B1035.1', 'F9 v1.1 B1015', 'F9 B4 B1041.1', 'F9 B4 B1039.1', 'F9 B5 B1049.2', 'F9 B5 B1058.3 ', 'F9 FT B1019', 'F9 B5 B1051.3', 'F9 B5 B1058.2 ', 'F9 FT  B1021.2', 'F9 FT  B1036.2', 'F9 FT B1024', 'F9 B5 B1049.5', 'F9 B5 B1058.4 ', 'F9 B5 B1048.3', 'F9 B5 B1049.3', 'F9 B5 B1048.4', 'F9 FT B1020', 'F9 B5 B1059.4', 'F9 B5 B1051.5', 'F9 FT  B1035.2', 'F9 v1.0  B0007', 'F9 FT  B1029.2', 'F9 B4 B1043.1', 'F9 FT B1030', 'F9 B5B1058.1 ', 'F9 B5B1059.1', 'F9 B5 B1046.3', 'F9 B5B1049.1', 'F9 v1.1 B1017', 'F9 B5 B1051.6', 'F9 B5 B1048.2', 'F9 FT B1038.1', 'F9 FT B1026', 'F9 FT B1023.1', 'F9 B5B1062.1', 'F9 v1.1 B1018', 'F9 B5 B1051.4', 'F9 B5B1051.1', 'F9 B5 B1059.2', 'F9 v1.1 B1016', 'F9 v1.0  B0005', 'F9 B5 B1047.3 ', 'F9 v1.1 B1010', 'F9 B5 B1049.6', 'F9 FT  B1038.2',
# ...

# %%
df_F9= df[df['Booster_Version'].str.contains('F9 v1.1')]

# %%
df_F9['PAYLOAD_MASS__KG_'].mean()
# Out:
# 2534.6666666666665

# %%
df_Date=df[['Date','Landing_Outcome']]

# %%
df_Date['Landing_Outcome'].value_counts()
# Out:
# Success                   38
# No attempt                21
# Success (drone ship)      14
# Success (ground pad)       9
# Controlled (ocean)         5
# Failure (drone ship)       5
# Failure                    3
# Failure (parachute)        2
# Uncontrolled (ocean)       2
# Precluded (drone ship)     1
# No attempt                 1
# Name: Landing_Outcome, dtype: int64

# %%
df_date= df_Date[df_Date['Landing_Outcome']=='Success (ground pad)']
df_date
# Out:
#           Date       Landing_Outcome
# 19  2015-12-22  Success (ground pad)
# 26  2016-07-18  Success (ground pad)
# 29  2017-02-19  Success (ground pad)
# 32  2017-05-01  Success (ground pad)
# 34  2017-06-03  Success (ground pad)
# 38  2017-08-14  Success (ground pad)
# 40  2017-09-07  Success (ground pad)
# 44  2017-12-15  Success (ground pad)
# 46  2018-01-08  Success (ground pad)

# %%
df_date.min()
# Out:
# Date                         2015-12-22
# Landing_Outcome    Success (ground pad)
# dtype: object

# %%
df[['Landing_Outcome','Mission_Outcome']]
# Out:
#          Landing_Outcome Mission_Outcome
# 0    Failure (parachute)         Success
# 1    Failure (parachute)         Success
# 2             No attempt         Success
# 3             No attempt         Success
# 4             No attempt         Success
# ..                   ...             ...
# 96               Success         Success
# 97               Success         Success
# 98               Success         Success
# 99               Success         Success
# 100              Success         Success
#
# [101 rows x 2 columns]

# %%
df['Landing_Outcome'].value_counts()
# Out:
# Success                   38
# No attempt                21
# Success (drone ship)      14
# Success (ground pad)       9
# Controlled (ocean)         5
# Failure (drone ship)       5
# Failure                    3
# Failure (parachute)        2
# Uncontrolled (ocean)       2
# Precluded (drone ship)     1
# No attempt                 1
# Name: Landing_Outcome, dtype: int64

# %%
df_Booster= df[['Booster_Version','Landing_Outcome','PAYLOAD_MASS__KG_']]
df_Booster
# Out:
#     Booster_Version      Landing_Outcome  PAYLOAD_MASS__KG_
# 0    F9 v1.0  B0003  Failure (parachute)                  0
# 1    F9 v1.0  B0004  Failure (parachute)                  0
# 2    F9 v1.0  B0005           No attempt                525
# 3    F9 v1.0  B0006           No attempt                500
# 4    F9 v1.0  B0007           No attempt                677
# ..              ...                  ...                ...
# 96     F9 B5B1062.1              Success               4311
# 97    F9 B5B1061.1               Success              12500
# 98     F9 B5B1063.1              Success               1192
# 99   F9 B5 B1049.7               Success              15600
# 100  F9 B5 B1058.4               Success               2972
#
# [101 rows x 3 columns]

# %%
df_boost= df.loc[(df_Booster['Landing_Outcome']=='Success (drone ship)')&(df_Booster['PAYLOAD_MASS__KG_']>4000)&(df_Booster['PAYLOAD_MASS__KG_']<6000)]

# %%
df_boost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 23 to 42
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               4 non-null      object
#  1   Time (UTC)         4 non-null      object
#  2   Booster_Version    4 non-null      object
#  3   Launch_Site        4 non-null      object
#  4   Payload            4 non-null      object
#  5   PAYLOAD_MASS__KG_  4 non-null      int64
#  6   Orbit              4 non-null      object
#  7   Customer           4 non-null      object
#  8   Mission_Outcome    4 non-null      object
#  9   Landing_Outcome    4 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 352.0+ bytes

# %%
set(df_boost['Booster_Version'])
# Out:
# {'F9 FT  B1021.2', 'F9 FT  B1031.2', 'F9 FT B1022', 'F9 FT B1026'}

# %%
df['Mission_Outcome'].value_counts()
# Out:
# Success                             98
# Failure (in flight)                  1
# Success (payload status unclear)     1
# Success                              1
# Name: Mission_Outcome, dtype: int64

# %%
df_max= df[['Booster_Version','PAYLOAD_MASS__KG_']]

# %%
Max_Payloadmass=df_max['PAYLOAD_MASS__KG_'].max()
Max_Payloadmass
# Out:
# 15600

# %%
print(set(df_boost_max['Booster_Version']))
# Out:
# {'F9 B5 B1060.2 ', 'F9 B5 B1051.4', 'F9 B5 B1058.3 ', 'F9 B5 B1049.7 ', 'F9 B5 B1049.4', 'F9 B5 B1051.3', 'F9 B5 B1048.4', 'F9 B5 B1056.4', 'F9 B5 B1049.5', 'F9 B5 B1051.6', 'F9 B5 B1048.5', 'F9 B5 B1060.3'}

# %%
import datetime

# %%
from datetime import date
df_9=df[['Date', 'Landing_Outcome', 'Booster_Version', 'Launch_Site']]
df_9
# Out:
#            Date      Landing_Outcome Booster_Version   Launch_Site
# 0    2010-06-04  Failure (parachute)  F9 v1.0  B0003   CCAFS LC-40
# 1    2010-12-08  Failure (parachute)  F9 v1.0  B0004   CCAFS LC-40
# 2    2012-05-22           No attempt  F9 v1.0  B0005   CCAFS LC-40
# 3    2012-10-08           No attempt  F9 v1.0  B0006   CCAFS LC-40
# 4    2013-03-01           No attempt  F9 v1.0  B0007   CCAFS LC-40
# ..          ...                  ...             ...           ...
# 96   2020-11-05              Success    F9 B5B1062.1  CCAFS SLC-40
# 97   2020-11-16              Success   F9 B5B1061.1     KSC LC-39A
# 98   2020-11-21              Success    F9 B5B1063.1   VAFB SLC-4E
# 99   2020-11-25              Success  F9 B5 B1049.7   CCAFS SLC-40
# 100  2020-12-06              Success  F9 B5 B1058.4     KSC LC-39A
#
# [101 rows x 4 columns]

# %%
df_9['Date'] = pd.to_datetime(df_9['Date'], format='%Y-%m-%d')
# Out:
# <ipython-input-120-46da38960471>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['Date'] = pd.to_datetime(df_9['Date'], format='%Y-%m-%d')

# %%
df_2015= df_9[df_9['Date'].dt.strftime('%Y')=='2015']
df_2015
# Out:
#          Date         Landing_Outcome Booster_Version  Launch_Site
# 13 2015-01-10    Failure (drone ship)   F9 v1.1 B1012  CCAFS LC-40
# 14 2015-02-11      Controlled (ocean)   F9 v1.1 B1013  CCAFS LC-40
# 15 2015-03-02              No attempt   F9 v1.1 B1014  CCAFS LC-40
# 16 2015-04-14    Failure (drone ship)   F9 v1.1 B1015  CCAFS LC-40
# 17 2015-04-27              No attempt   F9 v1.1 B1016  CCAFS LC-40
# 18 2015-06-28  Precluded (drone ship)   F9 v1.1 B1018  CCAFS LC-40
# 19 2015-12-22    Success (ground pad)     F9 FT B1019  CCAFS LC-40

# %%
df_month_name= df_2015[df_2015['Landing_Outcome']== 'Failure (drone ship)']
df_month_name
# Out:
#          Date       Landing_Outcome Booster_Version  Launch_Site
# 13 2015-01-10  Failure (drone ship)   F9 v1.1 B1012  CCAFS LC-40
# 16 2015-04-14  Failure (drone ship)   F9 v1.1 B1015  CCAFS LC-40

# %%
df_success_outcome = df.loc[(df['Date'] > '2010-06-06') & (df['Date'] < '2017-03-20') & df['Landing_Outcome'].str.contains('Success')]
df_success_outcome = df_success_outcome.sort_values(by='Date', ascending=False)
print(df_success_outcome['Date'])
# Out:
# 29    2017-02-19
# 28    2017-01-14
# 27    2016-08-14
# 26    2016-07-18
# 24    2016-05-27
# 23    2016-05-06
# 22    2016-04-08
# 19    2015-12-22
# Name: Date, dtype: object
